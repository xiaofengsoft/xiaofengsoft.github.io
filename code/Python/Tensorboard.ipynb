# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torch.utils.tensorboard import SummaryWriter

# 定义超参数
batch_size = 64
learning_rate = 0.001
num_epochs = 5

# 数据预处理
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))  # MNIST 数据集的均值和标准差
])

# 加载 MNIST 数据集
train_dataset = datasets.MNIST(
    root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(
    root='./data', train=False, download=True, transform=transform)

train_loader = DataLoader(dataset=train_dataset,
                          batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_dataset,
                         batch_size=batch_size, shuffle=False)

# 定义简单的 CNN 模型


class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(64 * 7 * 7, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = self.pool(torch.relu(self.conv2(x)))
        x = x.view(-1, 64 * 7 * 7)  # 展平
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x


# 初始化模型、损失函数和优化器
model = CNN()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# 初始化 TensorBoard
writer = SummaryWriter('logs/mnist_experiment')

# 训练模型
total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        # 前向传播
        outputs = model(images)
        loss = criterion(outputs, labels)

        # 反向传播和优化
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # 记录损失到 TensorBoard
        writer.add_scalar('Training Loss', loss.item(),
                          epoch * len(train_loader) + i)

        if (i + 1) % 100 == 0:
            print(
                f'Epoch [{epoch + 1}/{num_epochs}], Step [{i + 1}/{total_step}], Loss: {loss.item():.4f}')

    # 每个 epoch 结束后在测试集上评估模型
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in test_loader:
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    print(f'Test Accuracy after Epoch {epoch + 1}: {accuracy:.2f}%')
    writer.add_scalar('Test Accuracy', accuracy, epoch)

    model.train()

# 记录模型结构
images, _ = next(iter(train_loader))
writer.add_graph(model, images)


print("训练完成！")
# Out:
# Epoch [1/5], Step [100/938], Loss: 0.2888
# Epoch [1/5], Step [200/938], Loss: 0.1367
# Epoch [1/5], Step [300/938], Loss: 0.0563
# Epoch [1/5], Step [400/938], Loss: 0.1753
# Epoch [1/5], Step [500/938], Loss: 0.0923
# Epoch [1/5], Step [600/938], Loss: 0.0816
# Epoch [1/5], Step [700/938], Loss: 0.1019
# Epoch [1/5], Step [800/938], Loss: 0.0091
# Epoch [1/5], Step [900/938], Loss: 0.0359
# Test Accuracy after Epoch 1: 98.56%
# Epoch [2/5], Step [100/938], Loss: 0.0112
# Epoch [2/5], Step [200/938], Loss: 0.0062
# Epoch [2/5], Step [300/938], Loss: 0.0481
# Epoch [2/5], Step [400/938], Loss: 0.0359
# Epoch [2/5], Step [500/938], Loss: 0.0027
# Epoch [2/5], Step [600/938], Loss: 0.0217
# Epoch [2/5], Step [700/938], Loss: 0.0462
# Epoch [2/5], Step [800/938], Loss: 0.2010
# Epoch [2/5], Step [900/938], Loss: 0.0341
# Test Accuracy after Epoch 2: 98.75%
# Epoch [3/5], Step [100/938], Loss: 0.0509
# Epoch [3/5], Step [200/938], Loss: 0.0254
# Epoch [3/5], Step [300/938], Loss: 0.0209
# Epoch [3/5], Step [400/938], Loss: 0.0117
# Epoch [3/5], Step [500/938], Loss: 0.0065
# Epoch [3/5], Step [600/938], Loss: 0.0064
# Epoch [3/5], Step [700/938], Loss: 0.0336
# Epoch [3/5], Step [800/938], Loss: 0.0574
# Epoch [3/5], Step [900/938], Loss: 0.0078
# Test Accuracy after Epoch 3: 98.92%
# Epoch [4/5], Step [100/938], Loss: 0.0028
# Epoch [4/5], Step [200/938], Loss: 0.0040
# Epoch [4/5], Step [300/938], Loss: 0.0457
# Epoch [4/5], Step [400/938], Loss: 0.0014
# Epoch [4/5], Step [500/938], Loss: 0.0214
# Epoch [4/5], Step [600/938], Loss: 0.0128
# Epoch [4/5], Step [700/938], Loss: 0.0013
# Epoch [4/5], Step [800/938], Loss: 0.0030
# Epoch [4/5], Step [900/938], Loss: 0.0080
# Test Accuracy after Epoch 4: 99.23%
# Epoch [5/5], Step [100/938], Loss: 0.0008
# Epoch [5/5], Step [200/938], Loss: 0.0036
# Epoch [5/5], Step [300/938], Loss: 0.0450
# Epoch [5/5], Step [400/938], Loss: 0.0208
# Epoch [5/5], Step [500/938], Loss: 0.0422
# Epoch [5/5], Step [600/938], Loss: 0.0097
# Epoch [5/5], Step [700/938], Loss: 0.0210
# Epoch [5/5], Step [800/938], Loss: 0.0237
# Epoch [5/5], Step [900/938], Loss: 0.0068
# Test Accuracy after Epoch 5: 99.15%
# example_kwarg_inputs should be a dict
# Error occurs, No graph saved
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 99
#      97 # 记录模型结构
#      98 images, _ = next(iter(train_loader))
# ---> 99 writer.add_graph(model)
#     102 print("训练完成！")
#
# File d:\Python\CondaEnvs\Pytorch\lib\site-packages\torch\utils\tensorboard\writer.py:889, in SummaryWriter.add_graph(self, model, input_to_model, verbose, use_strict_trace)
#     885 torch._C._log_api_usage_once("tensorboard.logging.add_graph")
#     886 if hasattr(model, "forward"):
#     887     # A valid PyTorch model should have a 'forward' method
#     888     self._get_file_writer().add_graph(
# --> 889         graph(model, input_to_model, verbose, use_strict_trace)
#     890     )
#     891 else:
#     892     # Caffe2 models do not have the 'forward' method
#     893     from caffe2.proto import caffe2_pb2
#
# File d:\Python\CondaEnvs\Pytorch\lib\site-packages\torch\utils\tensorboard\_pytorch_graph.py:336, in graph(model, args, verbose, use_strict_trace)
#     334         print(e)
#     335         print("Error occurs, No graph saved")
# --> 336         raise e
#     338 if verbose:
#     339     print(graph)
#
# File d:\Python\CondaEnvs\Pytorch\lib\site-packages\torch\utils\tensorboard\_pytorch_graph.py:330, in graph(model, args, verbose, use_strict_trace)
#     328 with _set_model_to_eval(model):
#     329     try:
# --> 330         trace = torch.jit.trace(model, args, strict=use_strict_trace)
#     331         graph = trace.graph
#     332         torch._C._jit_pass_inline(graph)
#
# File d:\Python\CondaEnvs\Pytorch\lib\site-packages\torch\jit\_trace.py:819, in trace(func, example_inputs, optimize, check_trace, check_inputs, check_tolerance, strict, _force_outplace, _module_class, _compilation_unit, example_kwarg_inputs, _store_inputs)
#     817             example_inputs = example_kwarg_inputs
#     818         else:
# --> 819             raise RuntimeError("example_kwarg_inputs should be a dict")
#     820     return trace_module(
#     821         func,
#     822         {"forward": example_inputs},
#    (...)
#     831         _store_inputs=_store_inputs,
#     832     )
#     833 if (
#     834     hasattr(func, "__self__")
#     835     and isinstance(func.__self__, torch.nn.Module)
#     836     and func.__name__ == "forward"
#     837 ):
#
# RuntimeError: example_kwarg_inputs should be a dict

# %%
# 关闭 TensorBoard
writer.close()
